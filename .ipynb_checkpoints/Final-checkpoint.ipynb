# %%
# Data collection: OOI Regional Cabled Array Axial Seamount (Cruise Data)
# https://dataexplorer.oceanobservatories.org/#platform/fffe2293-19ad-55f4-83dd-1e97b5854063/v2?pid=23&tab=visualization

# %%
# Import statements
import pandas as pd
import matplotlib.pyplot as plt

# Importing my data and getting variables
df = pd.read_csv('ooi.csv', delimiter=',')
display(df)
temp = df['ctd_temperature_1'].values
con= df['ctd_conductivity_1'].values
oxygen = df['ctd_oxygen_saturation'].values
depth = df['depth'].values

# Creating my figures
plt.figure()
fig,(ax0,ax1,ax2) = plt.subplots(ncols=3, figsize=(20,10))

# Plot 1: Temperature vs Depth
ax0.scatter(temp,depth,c='mediumblue',s=70)
ax0.set_title('Temperature (°C) vs Depth (m)',fontsize=18)
ax0.set_xlabel('Temperature (°C)',fontsize=15)
ax0.set_ylabel('Depth (m)',fontsize=15)
ax0.invert_yaxis()
ax0.grid()

# Plot 2: Conductivity vs Depth
ax1.scatter(con,depth,c='orangered',s=70)
ax1.set_title('Conductivity (mS/cm) vs Depth (m)',fontsize=18)
ax1.set_xlabel('Conductivity (mS/cm)',fontsize=15)
ax1.set_ylabel('Depth (m)',fontsize=15)
ax1.invert_yaxis()
ax1.grid()

# Plot 3: Oxygen Saturation vs Depth
ax2.scatter(oxygen,depth,c='teal',s=70)
ax2.set_title('Oxygen Saturation (μmol/L) vs Depth (m)',fontsize=18)
ax2.set_xlabel('Oxygen Saturation (μmol/L)',fontsize=15)
ax2.set_ylabel('Depth (m)',fontsize=15)
ax2.invert_yaxis()
ax2.grid()
# Out:
#                                           FID                 time  profile
# 0      fffe2293-19ad-55f4-83dd-1e97b5854063.1  2017-07-27T23:37:00       16  \
# 1      fffe2293-19ad-55f4-83dd-1e97b5854063.2  2017-07-27T23:37:00       16
# 2      fffe2293-19ad-55f4-83dd-1e97b5854063.3  2017-07-27T23:37:00       16
# 3      fffe2293-19ad-55f4-83dd-1e97b5854063.4  2017-07-28T19:06:26        0
# 4      fffe2293-19ad-55f4-83dd-1e97b5854063.5  2017-07-28T19:06:26        0
# ..                                        ...                  ...      ...
# 122  fffe2293-19ad-55f4-83dd-1e97b5854063.123  2017-08-23T09:37:00       14
# 123  fffe2293-19ad-55f4-83dd-1e97b5854063.124  2017-08-25T23:32:00       15
# 124  fffe2293-19ad-55f4-83dd-1e97b5854063.125  2017-08-25T23:32:00       15
# 125  fffe2293-19ad-55f4-83dd-1e97b5854063.126  2017-08-25T23:32:00       15
# 126  fffe2293-19ad-55f4-83dd-1e97b5854063.127  2017-08-25T23:32:00       15
#
#           depth  segment      distance  start_latitude  start_longitude
# 0    220.391006        0  0.000000e+00        44.37405       -124.95625  \
# 1    220.391006        0  1.370000e+00        44.37406       -124.95624
# 2    220.391006        0  1.370000e+00        44.37406       -124.95624
# 3    550.835999        0  4.853000e+02        44.37417       -124.95017
# 4    401.492004        0  4.853000e+02        44.37417       -124.95017
# ..          ...      ...           ...             ...              ...
# 122  220.391006        0  1.976097e+06        45.82955       -129.75927
# 123  220.391006        0  2.387713e+06        44.36829       -124.95278
# 124  220.391006        0  2.387713e+06        44.36829       -124.95278
# 125  220.391006        0  2.387713e+06        44.36829       -124.95278
# 126  220.391006        0  2.387713e+06        44.36829       -124.95278
#
#               start_time  bottom_depth  ... calculated_alkalinity
# 0    2017-07-27T23:37:00          5000  ...                   NaN  \
# 1    2017-07-27T23:37:00          5000  ...                   NaN
# 2    2017-07-27T23:37:00          5000  ...                   NaN
# 3    2017-07-28T19:06:26          5000  ...                   NaN
# 4    2017-07-28T19:06:26          5000  ...                   NaN
# ..                   ...           ...  ...                   ...
# 122  2017-08-23T09:37:00          5000  ...                   NaN
# 123  2017-08-25T23:32:00          5000  ...                   NaN
# 124  2017-08-25T23:32:00          5000  ...                   NaN
# 125  2017-08-25T23:32:00          5000  ...                   NaN
# 126  2017-08-25T23:32:00          5000  ...                   NaN
#
#      calculated_ph  calculated_co2aq  calculated_bicarb  calculated_co3
# 0              NaN               NaN                NaN             NaN  \
# 1              NaN               NaN                NaN             NaN
# 2              NaN               NaN                NaN             NaN
# 3              NaN               NaN                NaN             NaN
# 4              NaN               NaN                NaN             NaN
# ..             ...               ...                ...             ...
# 122            NaN               NaN                NaN             NaN
# 123            NaN               NaN                NaN             NaN
# 124            NaN               NaN                NaN             NaN
# 125            NaN               NaN                NaN             NaN
# 126            NaN               NaN                NaN             NaN
#
#      calculated_omega_c  calculated_omega_a                         geom
# 0                   NaN                 NaN  POINT (-124.95625 44.37405)  \
# 1                   NaN                 NaN  POINT (-124.95624 44.37406)
# 2                   NaN                 NaN  POINT (-124.95624 44.37406)
# 3                   NaN                 NaN  POINT (-124.95017 44.37417)
# 4                   NaN                 NaN  POINT (-124.95017 44.37417)
# ..                  ...                 ...                          ...
# 122                 NaN                 NaN  POINT (-129.75927 45.82955)
# 123                 NaN                 NaN  POINT (-124.95278 44.36829)
# 124                 NaN                 NaN  POINT (-124.95278 44.36829)
# 125                 NaN                 NaN  POINT (-124.95278 44.36829)
# 126                 NaN                 NaN  POINT (-124.95278 44.36829)
#
#             source                                source_id
# 0    ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 1    ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 2    ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 3    ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 4    ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# ..             ...                                      ...
# 122  ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 123  ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 124  ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 125  ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
# 126  ooi.ocdi.ocdi  Cabled-8_RR1713-RR1717_Discrete_Summary
#
# [127 rows x 50 columns]
